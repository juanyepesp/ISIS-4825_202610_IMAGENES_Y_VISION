# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/juanyepesp/ISIS-4825_202610_IMAGENES_Y_VISION/blob/main/Laboratorio_08/Practica/MISIS4825_Laboratorio08_Practica.ipynb)

# %% [markdown]
# # Laboratorio 08 - Práctica: Redes Neuronales Convolucionales
#
# ## Objetivos
#
# - Entender los fundamentos y la arquitectura de las redes neuronales convolucionales (CNN).
# - Implementar una red convolucional simple para clasificación de imágenes.
# - Conocer el funcionamiento de capas clave: Conv2D, Pooling, Dropout, Flatten y Dense.
# - Hacer una búsqueda de hiperparámetros.
# - Entrenar, evaluar y comparar los modelos, analizando el impacto de cada componente.
#
#
# ## Contexto
#
# En esta práctica de laboratorio trabajaremos con el conjunto de datos **Face Emotion Dataset** para clasificar imágenes de emociones de personas.
#
# **Datos:** [Face Emotion Dataset](https://www.kaggle.com/datasets/nishchalchandel/raf-db-face-emotion-dataset/)

# %% [markdown]
# # Descarga y preparación del dataset
#
# En la práctica anterior vimos cómo se puede descargar un dataset utilizando la API de Kaggle. Esta vez lo vamos a hacer de forma más sencilla utilizando `curl` y `subprocess`

# %%
from pathlib import Path
import subprocess # https://docs.python.org/3/library/subprocess.html#subprocess.run

data_dir = Path("data")
data_dir.mkdir(parents=True, exist_ok=True)
zip_path = data_dir / "raf-db-face-emotion-dataset.zip"
url = "https://www.kaggle.com/api/v1/datasets/download/nishchalchandel/raf-db-face-emotion-dataset"

# %%
subprocess.run(["curl", "-L", "-o", str(zip_path), url], check=True, stdout=subprocess.DEVNULL, stderr=subprocess.STDOUT)
subprocess.run(["unzip", "-o", str(zip_path), "-d", str(data_dir)], check=True, stdout=subprocess.DEVNULL, stderr=subprocess.STDOUT)
zip_path.unlink(missing_ok=True)

# %% [markdown]
# # Exploración de los datos
#
# Podemos ver la distribución de las imágenes de entrenamiento y algunos ejemplos, para ver cómo se distribuyen nuestros datos. De Kaggle ya sabemos que hay tres subconjuntos, de entrenamiento, validacion y prueba, pero veamos la distribucion por clase de entrenamiento en primer lugar.

# %%
import matplotlib.pyplot as plt

train_path = data_dir / "train"
test_path = data_dir / "test"
validation_path = data_dir / "validation"

splits = {
    "Train": train_path,
    "Validation": validation_path,
    "Test": test_path,
}

split_data = {}
max_classes = 0

for split_name, split_path in splits.items():
    class_dirs = sorted([d for d in Path(split_path).iterdir() if d.is_dir()])
    labels, counts, samples = [], [], []

    for d in class_dirs:
        imgs = sorted([p for p in d.rglob("*") if p.is_file() and p.suffix.lower() == ".jpg"])
        if imgs:
            labels.append(d.name)
            counts.append(len(imgs))
            samples.append(imgs[0])

    split_data[split_name] = (labels, counts, samples)
    max_classes = max(max_classes, len(labels))

fig = plt.figure(figsize=(3.2 * (max_classes + 1), 3.4 * len(splits)))
gs = fig.add_gridspec(len(splits), max_classes + 1, width_ratios=[1.4] + [1] * max_classes)

for r, (split_name, (labels, counts, samples)) in enumerate(split_data.items()):
    ax_bar = fig.add_subplot(gs[r, 0])
    ax_bar.bar(labels, counts)
    ax_bar.set_title(f"{split_name} - Distribución")
    ax_bar.tick_params(axis="x", rotation=35)

    for c in range(max_classes):
        ax_img = fig.add_subplot(gs[r, c + 1])
        if c < len(labels):
            ax_img.imshow(plt.imread(samples[c]))
            ax_img.set_title(f"{labels[c]}\n(n={counts[c]})", fontsize=9)
        ax_img.axis("off")

plt.tight_layout()
plt.show()

# %% [markdown]
# # Preprocesamiento
#
# A continuación construiremos nuestros datasets de entrenamiento prueba y validación. Se crean DataFrames con las rutas de los archivos y sus etiquetas (la etiqueta se infiere del nombre de la carpeta). Anteriormente vimos en las distribuciones que los conjuntos están desbalanceados, para manejar esto hay muchas opciones, tales como hacer muestreos de los datos, aumentaciones, etc. De esto nos encargaremos más adelante.
#
# **Nota:** En este laboratorio no se aplican transformaciones complejas (como ecualización de histograma o filtros), sino que solo se reescala la imagen. En la discusión se analizará qué efectos podría tener aplicar técnicas adicionales de preprocesamiento.

# %%
import pandas as pd

def build_dataframe(root_path):
    filepaths = [str(p) for p in root_path.rglob("*.jpg")]
    labels = [p.parent.name for p in map(Path, filepaths)]
    return pd.DataFrame({"filepath": filepaths, "label": labels})

train_df = build_dataframe(train_path)
test_df = build_dataframe(test_path)
validation_df = build_dataframe(validation_path)

def split_y(df, column):
    return df.drop(column, axis=1), df[column]

X_train, y_train = split_y(train_df, 'label')
X_val, y_val = split_y(validation_df, 'label')
X_test, y_test = split_y(test_df, 'label')

# %% [markdown]
# Se utilizan los generadores de datos de Keras para cargar las imágenes en tiempo real.
#
# - Para el conjunto de entrenamiento se aplica data augmentation (rotación, volteo) para mejorar la robustez del modelo.
# - Para validación y test, solo se reescala la imagen.
# - Se calculan también los pesos de las clases. Esto es con el fin de que el modelo le "preste más atención" a las clases con menos muestras, con el fin de contrarrestar el desbalance que existe.

# %%
from tensorflow import keras
from sklearn.utils.class_weight import compute_class_weight


train_datagen = keras.preprocessing.image.ImageDataGenerator(
    rescale=1.0 / 255.0,
    rotation_range=10,
    width_shift_range=0.05,
    height_shift_range=0.05,
    zoom_range=0.10,
    horizontal_flip=True,
    fill_mode="nearest",
)

eval_datagen = keras.preprocessing.image.ImageDataGenerator(rescale=1.0 / 255.0)

def make_flow(datagen, X_split, y_split, shuffle):
    df = X_split.copy()
    df["label"] = y_split.values
    return datagen.flow_from_dataframe(
        dataframe=df,
        x_col="filepath",
        y_col="label",
        target_size=(100, 100),
        color_mode="grayscale",
        class_mode="categorical",
        classes=labels,
        batch_size=32,
        shuffle=shuffle,
        seed=42,
    )

train = make_flow(train_datagen, X_train, y_train, shuffle=True)
val = make_flow(eval_datagen, X_val, y_val, shuffle=False)
test = make_flow(eval_datagen, X_test, y_test, shuffle=False)

classes = np.unique(y_train.values)
weights = compute_class_weight(class_weight="balanced", classes=classes, y=y_train.values)
class_weight = dict(zip(classes, weights))
# Out:
# Found 12271 validated image filenames belonging to 7 classes.
# Found 1533 validated image filenames belonging to 7 classes.
# Found 1535 validated image filenames belonging to 7 classes.

# %% [markdown]
# ## Construcción del Modelo
# Se implementa una red neuronal convolucional simple con las siguientes capas:
#
# - `Conv2D:` Aplica filtros aprendibles para extraer características de la imagen.
# - `Pooling (MaxPooling2D):` Reduce la dimensión espacial, ayudando a la invariancia a traslaciones y reduciendo el cómputo. Existen otros tipos de pooling que también pueden implementar en la arquitectura como AveragePooling2D, GlobalMaxPooling2D y GlobalAveragePooling2D.
# - `BatchNormalization` Es una capa que normaliza las salidas de la capa anterior para que tengan una distribución más estable (media cercana a 0 y desviación estándar cercana a 1).
# - `Activation` Es la función encargada de introducir no linealidad en la red neuronal aplicando una transformación matemática a la salida de la capa anterior.
# - `Flatten:` Convierte la salida multidimensional en un vector unidimensional.
# - `Dense:` Capas completamente conectadas para la clasificación.
# - `Dropout:` Regularización para prevenir el sobreajuste.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout


model = keras.Sequential([
    layers.Conv2D(32, (3, 3), padding="same", input_shape=(100, 100, 1)),
    layers.BatchNormalization(),
    layers.Activation("relu"),
    layers.MaxPooling2D((2, 2)),

    layers.Conv2D(64, (3, 3), padding="same"),
    layers.BatchNormalization(),
    layers.Activation("relu"),
    layers.MaxPooling2D((2, 2)),

    layers.Conv2D(128, (3, 3), padding="same"),
    layers.BatchNormalization(),
    layers.Activation("relu"),
    layers.MaxPooling2D((2, 2)),

    layers.Flatten(),
    layers.Dense(128, activation="relu"),
    layers.Dropout(0.3),
    layers.Dense(7, activation="softmax"),
])

model.summary()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 6
#       2 from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
#       3
#       4
#       5 model = keras.Sequential([
# ----> 6     layers.Conv2D(32, (3, 3), padding="same", input_shape=(100, 100, 1)),
#       7     layers.BatchNormalization(),
#       8     layers.Activation("relu"),
#       9     layers.MaxPooling2D((2, 2)),
#
# NameError: name 'layers' is not defined

# %% [markdown]
# # Compilación
#
# Se compila el modelo definiendo el optimizador, la función de pérdida y la métrica de evaluación. Utilizamos el optimizador **adam** y la función de pérdida **categorical_crossentropy** adecuada para clasificación multiclase.

# %%
model.compile(optimizer=keras.optimizers.Adam(1e-3),
              loss="categorical_crossentropy",
              metrics=["accuracy"])

# %% [markdown]
# Se utilizan callbacks para:
#
# - `ModelCheckpoint` Guardar el modelo que presente la menor pérdida en validación.
# - `EarlyStopping` Detener el entrenamiento si la métrica de validación no mejora.
# - `ReduceLROnPlateau` Reducir la tasa de aprendizaje cuando la métrica se estabiliza.

# %%
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint

model_checkpoint = ModelCheckpoint('best_model.keras', save_best_only=True, monitor='val_loss', mode='min')
early_stopping = EarlyStopping(monitor='val_loss', patience=10, verbose=1, mode='min')
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=5, verbose=1, mode='min')

callbacks = [model_checkpoint, early_stopping, reduce_lr]

# %% [markdown]
# # Entrenamiento del primer modelo
# Se entrena la red convolucional utilizando el conjunto de entrenamiento y se valida con el de validación. Se recomienda experimentar modificando el número de épocas para observar el comportamiento del entrenamiento.

# %%
import tensorflow as tf

if tf.config.list_physical_devices('GPU'):
    print("GPU is available. Training on GPU.")
    with tf.device('/GPU:0'):
      history = model.fit(
          train,
          validation_data=val,
          epochs=50,
          callbacks=callbacks,
          class_weight=class_weight,
      )
else:
    print("GPU is not available. Training on CPU.")
    history = model.fit(
        train,
        validation_data=val,
        epochs=50,
        callbacks=callbacks,
        class_weight=class_weight,
    )

test_loss, test_acc = model.evaluate(test)
# Out:
# GPU is available. Training on GPU.
# Epoch 1/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 33s 72ms/step - accuracy: 0.3836 - loss: 1.8752 - val_accuracy: 0.3999 - val_loss: 1.6776 - learning_rate: 0.0010
# Epoch 2/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 22s 57ms/step - accuracy: 0.4338 - loss: 1.4753 - val_accuracy: 0.4912 - val_loss: 1.3241 - learning_rate: 0.0010
# Epoch 3/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 23s 59ms/step - accuracy: 0.4600 - loss: 1.4199 - val_accuracy: 0.4912 - val_loss: 1.4249 - learning_rate: 0.0010
# Epoch 4/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 21s 54ms/step - accuracy: 0.4729 - loss: 1.3756 - val_accuracy: 0.5597 - val_loss: 1.2784 - learning_rate: 0.0010
# Epoch 5/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 22s 56ms/step - accuracy: 0.4819 - loss: 1.3547 - val_accuracy: 0.5258 - val_loss: 1.3347 - learning_rate: 0.0010
# Epoch 6/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 22s 57ms/step - accuracy: 0.4912 - loss: 1.3274 - val_accuracy: 0.5799 - val_loss: 1.2057 - learning_rate: 0.0010
# Epoch 7/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 21s 54ms/step - accuracy: 0.4906 - loss: 1.3029 - val_accuracy: 0.5662 - val_loss: 1.1479 - learning_rate: 0.0010
# Epoch 8/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 23s 59ms/step - accuracy: 0.4978 - loss: 1.2970 - val_accuracy: 0.5995 - val_loss: 1.1480 - learning_rate: 0.0010
# Epoch 9/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 23s 60ms/step - accuracy: 0.5010 - loss: 1.2886 - val_accuracy: 0.6158 - val_loss: 1.1387 - learning_rate: 0.0010
# Epoch 10/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 22s 58ms/step - accuracy: 0.5064 - loss: 1.2871 - val_accuracy: 0.6217 - val_loss: 1.1603 - learning_rate: 0.0010
# Epoch 11/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 21s 55ms/step - accuracy: 0.5105 - loss: 1.2796 - val_accuracy: 0.6099 - val_loss: 1.1808 - learning_rate: 0.0010
# Epoch 12/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 22s 58ms/step - accuracy: 0.5133 - loss: 1.2649 - val_accuracy: 0.6230 - val_loss: 1.1109 - learning_rate: 0.0010
# Epoch 13/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 22s 58ms/step - accuracy: 0.5230 - loss: 1.2528 - val_accuracy: 0.6380 - val_loss: 1.1016 - learning_rate: 0.0010
# Epoch 14/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 21s 55ms/step - accuracy: 0.5230 - loss: 1.2458 - val_accuracy: 0.5838 - val_loss: 1.2607 - learning_rate: 0.0010
# Epoch 15/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 22s 57ms/step - accuracy: 0.5262 - loss: 1.2388 - val_accuracy: 0.6295 - val_loss: 1.1390 - learning_rate: 0.0010
# Epoch 16/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 22s 57ms/step - accuracy: 0.5215 - loss: 1.2387 - val_accuracy: 0.6301 - val_loss: 1.1066 - learning_rate: 0.0010
# Epoch 17/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 22s 57ms/step - accuracy: 0.5277 - loss: 1.2295 - val_accuracy: 0.6517 - val_loss: 1.0664 - learning_rate: 0.0010
# Epoch 18/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 41s 58ms/step - accuracy: 0.5350 - loss: 1.2092 - val_accuracy: 0.6399 - val_loss: 1.0436 - learning_rate: 0.0010
# Epoch 19/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 22s 58ms/step - accuracy: 0.5317 - loss: 1.2134 - val_accuracy: 0.6367 - val_loss: 1.0918 - learning_rate: 0.0010
# Epoch 20/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 21s 55ms/step - accuracy: 0.5381 - loss: 1.2080 - val_accuracy: 0.6445 - val_loss: 1.0582 - learning_rate: 0.0010
# Epoch 21/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 22s 58ms/step - accuracy: 0.5401 - loss: 1.2018 - val_accuracy: 0.6327 - val_loss: 1.0629 - learning_rate: 0.0010
# Epoch 22/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 22s 58ms/step - accuracy: 0.5394 - loss: 1.2032 - val_accuracy: 0.6471 - val_loss: 1.0393 - learning_rate: 0.0010
# Epoch 23/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 22s 57ms/step - accuracy: 0.5445 - loss: 1.1861 - val_accuracy: 0.6491 - val_loss: 1.0176 - learning_rate: 0.0010
# Epoch 24/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 22s 58ms/step - accuracy: 0.5533 - loss: 1.1710 - val_accuracy: 0.6569 - val_loss: 0.9943 - learning_rate: 0.0010
# Epoch 25/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 23s 59ms/step - accuracy: 0.5461 - loss: 1.1798 - val_accuracy: 0.6712 - val_loss: 0.9849 - learning_rate: 0.0010
# Epoch 26/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 22s 58ms/step - accuracy: 0.5573 - loss: 1.1682 - val_accuracy: 0.6791 - val_loss: 0.9881 - learning_rate: 0.0010
# Epoch 27/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 21s 56ms/step - accuracy: 0.5518 - loss: 1.1700 - val_accuracy: 0.6523 - val_loss: 1.0443 - learning_rate: 0.0010
# Epoch 28/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 22s 58ms/step - accuracy: 0.5608 - loss: 1.1544 - val_accuracy: 0.6491 - val_loss: 1.0140 - learning_rate: 0.0010
# Epoch 29/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 22s 57ms/step - accuracy: 0.5564 - loss: 1.1550 - val_accuracy: 0.6784 - val_loss: 0.9806 - learning_rate: 0.0010
# Epoch 30/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 21s 55ms/step - accuracy: 0.5567 - loss: 1.1632 - val_accuracy: 0.6882 - val_loss: 0.9856 - learning_rate: 0.0010
# Epoch 31/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 22s 57ms/step - accuracy: 0.5587 - loss: 1.1469 - val_accuracy: 0.6928 - val_loss: 0.9390 - learning_rate: 0.0010
# Epoch 32/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 22s 56ms/step - accuracy: 0.5669 - loss: 1.1401 - val_accuracy: 0.6869 - val_loss: 0.9560 - learning_rate: 0.0010
# Epoch 33/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 21s 56ms/step - accuracy: 0.5696 - loss: 1.1318 - val_accuracy: 0.6706 - val_loss: 0.9953 - learning_rate: 0.0010
# Epoch 34/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 42s 57ms/step - accuracy: 0.5777 - loss: 1.1256 - val_accuracy: 0.6673 - val_loss: 1.0034 - learning_rate: 0.0010
# Epoch 35/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 22s 58ms/step - accuracy: 0.5688 - loss: 1.1349 - val_accuracy: 0.7104 - val_loss: 0.9138 - learning_rate: 0.0010
# Epoch 36/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 21s 56ms/step - accuracy: 0.5743 - loss: 1.1309 - val_accuracy: 0.7084 - val_loss: 0.9003 - learning_rate: 0.0010
# Epoch 37/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 22s 58ms/step - accuracy: 0.5805 - loss: 1.1213 - val_accuracy: 0.7045 - val_loss: 0.8979 - learning_rate: 0.0010
# Epoch 38/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 23s 59ms/step - accuracy: 0.5796 - loss: 1.1158 - val_accuracy: 0.6973 - val_loss: 0.9572 - learning_rate: 0.0010
# Epoch 39/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 22s 57ms/step - accuracy: 0.5804 - loss: 1.1150 - val_accuracy: 0.6960 - val_loss: 0.9155 - learning_rate: 0.0010
# Epoch 40/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 22s 56ms/step - accuracy: 0.5777 - loss: 1.1135 - val_accuracy: 0.6830 - val_loss: 0.9327 - learning_rate: 0.0010
# Epoch 41/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 22s 58ms/step - accuracy: 0.5832 - loss: 1.1060 - val_accuracy: 0.7156 - val_loss: 0.9046 - learning_rate: 0.0010
# Epoch 42/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.5914 - loss: 1.1075
# Epoch 42: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 22s 58ms/step - accuracy: 0.5879 - loss: 1.1104 - val_accuracy: 0.6921 - val_loss: 0.9443 - learning_rate: 0.0010
# Epoch 43/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 22s 57ms/step - accuracy: 0.5893 - loss: 1.0866 - val_accuracy: 0.7293 - val_loss: 0.8701 - learning_rate: 1.0000e-04
# Epoch 44/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 23s 59ms/step - accuracy: 0.5964 - loss: 1.0764 - val_accuracy: 0.7221 - val_loss: 0.8699 - learning_rate: 1.0000e-04
# Epoch 45/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 22s 58ms/step - accuracy: 0.6004 - loss: 1.0631 - val_accuracy: 0.7273 - val_loss: 0.8604 - learning_rate: 1.0000e-04
# Epoch 46/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 22s 57ms/step - accuracy: 0.5978 - loss: 1.0679 - val_accuracy: 0.7234 - val_loss: 0.8646 - learning_rate: 1.0000e-04
# Epoch 47/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 22s 58ms/step - accuracy: 0.6036 - loss: 1.0582 - val_accuracy: 0.7299 - val_loss: 0.8604 - learning_rate: 1.0000e-04
# Epoch 48/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 23s 59ms/step - accuracy: 0.5984 - loss: 1.0647 - val_accuracy: 0.7352 - val_loss: 0.8559 - learning_rate: 1.0000e-04
# Epoch 49/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 23s 59ms/step - accuracy: 0.6014 - loss: 1.0591 - val_accuracy: 0.7345 - val_loss: 0.8531 - learning_rate: 1.0000e-04
# Epoch 50/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 22s 57ms/step - accuracy: 0.5948 - loss: 1.0665 - val_accuracy: 0.7332 - val_loss: 0.8508 - learning_rate: 1.0000e-04
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 0.7238 - loss: 0.8509

# %% [markdown]
# ## Análisis del Entrenamiento del Modelo Base
#
# Vamos a visualizar la progresión de la precisión (accuracy) y la pérdida (loss) durante el entrenamiento de nuestro modelo base, al igual que la matriz de confusión. Esto nos permitirá identificar si el modelo está aprendiendo, si hay sobreajuste (overfitting) o subajuste (underfitting), y cómo se comporta en los datos de validación.

# %%
import matplotlib.pyplot as plt

def plot_training_history(history):
    fig, axs = plt.subplots(1, 2, figsize=(15, 5))

    # Plot training & validation accuracy values
    axs[0].plot(history.history['accuracy'])
    axs[0].plot(history.history['val_accuracy'])
    axs[0].set_title('Model Accuracy')
    axs[0].set_ylabel('Accuracy')
    axs[0].set_xlabel('Epoch')
    axs[0].legend(['Train', 'Validation'], loc='upper left')
    axs[0].grid(True)

    # Plot training & validation loss values
    axs[1].plot(history.history['loss'])
    axs[1].plot(history.history['val_loss'])
    axs[1].set_title('Model Loss')
    axs[1].set_ylabel('Loss')
    axs[1].set_xlabel('Epoch')
    axs[1].legend(['Train', 'Validation'], loc='upper left')
    axs[1].grid(True)

    plt.tight_layout()
    plt.show()

plot_training_history(history)

# %%
import numpy as np
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay


y_true = test.classes
y_pred_probabilities = model.predict(test)
y_pred = np.argmax(y_pred_probabilities, axis=1)
class_names = list(test.class_indices.keys())
cm = confusion_matrix(y_true, y_pred)


fig, ax = plt.subplots(figsize=(10, 8))
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_names)
disp.plot(cmap=plt.cm.Blues, ax=ax, xticks_rotation='vertical')
plt.title('Confusion Matrix')
plt.show()
# Out:
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step

# %%
from sklearn.metrics import classification_report

print(classification_report(
    y_true,
    y_pred,
    labels=range(len(class_names)),
    target_names=class_names,
    digits=4,
    zero_division=0
))

# %% [markdown]
# En nuestro caso el modelo no tiene malas métricas, la precisión  de validación y entrenamiento crecen progresivamente, al igual que las funciones de pérdida disminuyen, sin evidencia clara de sobreajuste. Sin embargo, este es nuestro primer modelo, y se pueden aplicar algunas técnicas para mejorar las métricas.

# %% [markdown]
# # Búsqueda de hiperparámetros
#
# Ahora con base a nuestro modelo anterior, vamos a hacer una búsqueda de hiperparámetros utilizando `keras_tuner`. Esto nos va a permitir entrenar varios modelos cambiando algunos hiperparámetros de arquitectura. En este caso, cambiaremos el tamaño de los filtros convolucionales, la tasa de aprendizaje, entre otros. Utilizamos un random tuner para que escoja el número de combinaciones aleatorias que definamos, y de allí escoja la mejor. Existen muchas combinaciones posibles para hacer esta búsqueda, se encuentran en la [documentación oficial](https://keras.io/keras_tuner/). Finalmente también se suaviza un poco los pesos de las clases ya que se evidencia en la matriz de confusión que se dejan de lado algunas clases.

# %%
classes = np.unique(y_train.values)
weights = compute_class_weight(
    class_weight='balanced',
    classes=classes,
    y=y_train.values
)
class_weight = dict(zip(classes, weights))

alpha = 0.5
class_weight_scaled = {
    k: v**alpha for k, v in class_weight.items()
}

# %%
import keras_tuner as kt

def build_model(hp):
    model = keras.Sequential([
        layers.Conv2D(
            filters=hp.Choice('filters_1', [32, 64]),
            kernel_size=(3, 3),
            padding='same',
            activation='relu',
            input_shape=(100, 100, 1)
        ),
        layers.MaxPooling2D(2),

        layers.Conv2D(
            filters=hp.Choice('filters_2', [64, 128]),
            kernel_size=(3, 3),
            padding='same',
            activation='relu'
        ),
        layers.MaxPooling2D(2),

        layers.Flatten(),

        layers.Dense(
            units=hp.Choice('dense_units', [64, 128, 256]),
            activation='relu'
        ),

        layers.Dropout(hp.Float('dropout', 0.3, 0.6, step=0.1)),

        layers.Dense(7, activation='softmax')
    ])

    lr = hp.Choice('learning_rate', [1e-3, 5e-4, 1e-4])

    model.compile(
        optimizer=keras.optimizers.Adam(learning_rate=lr),
        loss='categorical_crossentropy',
        metrics=['accuracy']
    )

    return model

# %%
tuner = kt.RandomSearch(
    build_model,
    objective='val_accuracy',
    max_trials=8,
    directory='tuner_dir',
    project_name='cnn_gen_tune'
)
# Out:
# Reloading Tuner from tuner_dir/cnn_gen_tune/tuner0.json

# %%
history = tuner.search(
    train,
    validation_data=val,
    epochs=10,
    callbacks=callbacks,
    class_weight=class_weight_scaled
)

# %%
best_model = tuner.get_best_models(1)[0]

history = best_model.fit(
    train,
    validation_data=val,
    epochs=50,
    callbacks=callbacks,
    class_weight=class_weight_scaled
)
test_loss, test_acc = best_model.evaluate(test)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.12/dist-packages/keras/src/saving/saving_lib.py:797: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 18 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# Epoch 1/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 27s 63ms/step - accuracy: 0.4961 - loss: 1.3666 - val_accuracy: 0.6125 - val_loss: 1.1222 - learning_rate: 5.0000e-04
# Epoch 2/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 23s 59ms/step - accuracy: 0.5578 - loss: 1.2164 - val_accuracy: 0.6523 - val_loss: 0.9940 - learning_rate: 5.0000e-04
# Epoch 3/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 21s 53ms/step - accuracy: 0.5952 - loss: 1.1210 - val_accuracy: 0.6888 - val_loss: 0.9014 - learning_rate: 5.0000e-04
# Epoch 4/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 23s 59ms/step - accuracy: 0.6167 - loss: 1.0574 - val_accuracy: 0.6732 - val_loss: 0.9125 - learning_rate: 5.0000e-04
# Epoch 5/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 23s 60ms/step - accuracy: 0.6393 - loss: 1.0160 - val_accuracy: 0.7156 - val_loss: 0.8213 - learning_rate: 5.0000e-04
# Epoch 6/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 22s 57ms/step - accuracy: 0.6413 - loss: 0.9803 - val_accuracy: 0.7202 - val_loss: 0.7955 - learning_rate: 5.0000e-04
# Epoch 7/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 41s 58ms/step - accuracy: 0.6594 - loss: 0.9564 - val_accuracy: 0.7339 - val_loss: 0.7637 - learning_rate: 5.0000e-04
# Epoch 8/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 21s 55ms/step - accuracy: 0.6624 - loss: 0.9338 - val_accuracy: 0.7149 - val_loss: 0.8039 - learning_rate: 5.0000e-04
# Epoch 9/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 21s 55ms/step - accuracy: 0.6714 - loss: 0.9066 - val_accuracy: 0.7430 - val_loss: 0.7424 - learning_rate: 5.0000e-04
# Epoch 10/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 22s 58ms/step - accuracy: 0.6783 - loss: 0.8896 - val_accuracy: 0.7482 - val_loss: 0.7218 - learning_rate: 5.0000e-04
# Epoch 11/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 22s 56ms/step - accuracy: 0.6946 - loss: 0.8611 - val_accuracy: 0.7352 - val_loss: 0.7559 - learning_rate: 5.0000e-04
# Epoch 12/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 21s 56ms/step - accuracy: 0.6915 - loss: 0.8569 - val_accuracy: 0.7462 - val_loss: 0.7076 - learning_rate: 5.0000e-04
# Epoch 13/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 22s 56ms/step - accuracy: 0.6957 - loss: 0.8458 - val_accuracy: 0.7449 - val_loss: 0.7077 - learning_rate: 5.0000e-04
# Epoch 14/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 22s 56ms/step - accuracy: 0.7023 - loss: 0.8305 - val_accuracy: 0.7449 - val_loss: 0.7041 - learning_rate: 5.0000e-04
# Epoch 15/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 42s 58ms/step - accuracy: 0.7064 - loss: 0.8129 - val_accuracy: 0.7684 - val_loss: 0.6650 - learning_rate: 5.0000e-04
# Epoch 16/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 22s 56ms/step - accuracy: 0.7142 - loss: 0.8046 - val_accuracy: 0.7554 - val_loss: 0.6757 - learning_rate: 5.0000e-04
# Epoch 17/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 21s 54ms/step - accuracy: 0.7142 - loss: 0.7937 - val_accuracy: 0.7697 - val_loss: 0.6555 - learning_rate: 5.0000e-04
# Epoch 18/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 22s 56ms/step - accuracy: 0.7173 - loss: 0.7789 - val_accuracy: 0.7717 - val_loss: 0.6585 - learning_rate: 5.0000e-04
# Epoch 19/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 22s 56ms/step - accuracy: 0.7224 - loss: 0.7693 - val_accuracy: 0.7769 - val_loss: 0.6600 - learning_rate: 5.0000e-04
# Epoch 20/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 21s 54ms/step - accuracy: 0.7258 - loss: 0.7669 - val_accuracy: 0.7547 - val_loss: 0.6814 - learning_rate: 5.0000e-04
# Epoch 21/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 21s 56ms/step - accuracy: 0.7299 - loss: 0.7508 - val_accuracy: 0.7613 - val_loss: 0.6719 - learning_rate: 5.0000e-04
# Epoch 22/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.7358 - loss: 0.7378
# Epoch 22: ReduceLROnPlateau reducing learning rate to 5.0000002374872565e-05.
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 21s 55ms/step - accuracy: 0.7348 - loss: 0.7454 - val_accuracy: 0.7599 - val_loss: 0.6801 - learning_rate: 5.0000e-04
# Epoch 23/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 42s 57ms/step - accuracy: 0.7457 - loss: 0.7078 - val_accuracy: 0.7782 - val_loss: 0.6342 - learning_rate: 5.0000e-05
# Epoch 24/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 22s 56ms/step - accuracy: 0.7507 - loss: 0.6962 - val_accuracy: 0.7697 - val_loss: 0.6362 - learning_rate: 5.0000e-05
# Epoch 25/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 21s 54ms/step - accuracy: 0.7552 - loss: 0.6795 - val_accuracy: 0.7789 - val_loss: 0.6360 - learning_rate: 5.0000e-05
# Epoch 26/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 22s 58ms/step - accuracy: 0.7564 - loss: 0.6769 - val_accuracy: 0.7743 - val_loss: 0.6313 - learning_rate: 5.0000e-05
# Epoch 27/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 21s 55ms/step - accuracy: 0.7573 - loss: 0.6769 - val_accuracy: 0.7704 - val_loss: 0.6414 - learning_rate: 5.0000e-05
# Epoch 28/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 21s 55ms/step - accuracy: 0.7580 - loss: 0.6834 - val_accuracy: 0.7841 - val_loss: 0.6266 - learning_rate: 5.0000e-05
# Epoch 29/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 22s 56ms/step - accuracy: 0.7615 - loss: 0.6696 - val_accuracy: 0.7815 - val_loss: 0.6310 - learning_rate: 5.0000e-05
# Epoch 30/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 21s 55ms/step - accuracy: 0.7609 - loss: 0.6742 - val_accuracy: 0.7873 - val_loss: 0.6272 - learning_rate: 5.0000e-05
# Epoch 31/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 41s 56ms/step - accuracy: 0.7619 - loss: 0.6660 - val_accuracy: 0.7782 - val_loss: 0.6310 - learning_rate: 5.0000e-05
# Epoch 32/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 21s 55ms/step - accuracy: 0.7604 - loss: 0.6681 - val_accuracy: 0.7776 - val_loss: 0.6303 - learning_rate: 5.0000e-05
# Epoch 33/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 42s 58ms/step - accuracy: 0.7636 - loss: 0.6609 - val_accuracy: 0.7808 - val_loss: 0.6244 - learning_rate: 5.0000e-05
# Epoch 34/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 22s 57ms/step - accuracy: 0.7681 - loss: 0.6619 - val_accuracy: 0.7900 - val_loss: 0.6274 - learning_rate: 5.0000e-05
# Epoch 35/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 20s 53ms/step - accuracy: 0.7681 - loss: 0.6547 - val_accuracy: 0.7873 - val_loss: 0.6280 - learning_rate: 5.0000e-05
# Epoch 36/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 22s 56ms/step - accuracy: 0.7640 - loss: 0.6640 - val_accuracy: 0.7782 - val_loss: 0.6395 - learning_rate: 5.0000e-05
# Epoch 37/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 21s 55ms/step - accuracy: 0.7667 - loss: 0.6563 - val_accuracy: 0.7841 - val_loss: 0.6247 - learning_rate: 5.0000e-05
# Epoch 38/50
# 383/384 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.7714 - loss: 0.6363
# Epoch 38: ReduceLROnPlateau reducing learning rate to 5.000000237487257e-06.
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 21s 54ms/step - accuracy: 0.7671 - loss: 0.6505 - val_accuracy: 0.7828 - val_loss: 0.6279 - learning_rate: 5.0000e-05
# Epoch 39/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 22s 57ms/step - accuracy: 0.7701 - loss: 0.6522 - val_accuracy: 0.7841 - val_loss: 0.6286 - learning_rate: 5.0000e-06
# Epoch 40/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 21s 55ms/step - accuracy: 0.7655 - loss: 0.6533 - val_accuracy: 0.7815 - val_loss: 0.6261 - learning_rate: 5.0000e-06
# Epoch 41/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 21s 55ms/step - accuracy: 0.7679 - loss: 0.6439 - val_accuracy: 0.7867 - val_loss: 0.6267 - learning_rate: 5.0000e-06
# Epoch 42/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 22s 57ms/step - accuracy: 0.7678 - loss: 0.6482 - val_accuracy: 0.7841 - val_loss: 0.6258 - learning_rate: 5.0000e-06
# Epoch 43/50
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.7638 - loss: 0.6476
# Epoch 43: ReduceLROnPlateau reducing learning rate to 5.000000328436726e-07.
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 21s 54ms/step - accuracy: 0.7657 - loss: 0.6482 - val_accuracy: 0.7867 - val_loss: 0.6247 - learning_rate: 5.0000e-06
# Epoch 43: early stopping
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - accuracy: 0.7883 - loss: 0.6092

# %%
plot_training_history(history)

# %%
y_true = test.classes
y_pred_probabilities = best_model.predict(test)
y_pred = np.argmax(y_pred_probabilities, axis=1)
class_names = list(test.class_indices.keys())
cm = confusion_matrix(y_true, y_pred)


fig, ax = plt.subplots(figsize=(10, 8))
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_names)
disp.plot(cmap=plt.cm.Blues, ax=ax, xticks_rotation='vertical')
plt.title('Confusion Matrix')
plt.show()
# Out:
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step

# %%
print(classification_report(
    y_true,
    y_pred,
    labels=range(len(class_names)),
    target_names=class_names,
    digits=4,
    zero_division=0
))

# %% [markdown]
# ## Conclusiones y Discusión
#
# - **¿Cómo afecta el tamaño del filtro en las capas convolucionales al rendimiento del modelo?**
#
# - **¿Qué ventajas y desventajas presentan las diferentes estrategias de pooling (MaxPooling, AveragePooling, GlobalPooling) en la extracción de características?**
#
# - **¿Cómo influye la profundidad de la red (número de capas convolucionales) en la capacidad de generalización y el riesgo de sobreajuste?**
#
# - **¿Qué impacto tiene el uso de técnicas como Dropout o Batch Normalization en el entrenamiento de redes convolucionales?**
#
# - **¿Por qué es importante hacer la búsqueda de hiperparámetros?**
